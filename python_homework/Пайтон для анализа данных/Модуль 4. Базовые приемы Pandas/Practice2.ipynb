# %%
import pandas as pd

bike_data = pd.read_csv('C:\IDE\python_homework\Пайтон для анализа данных\Модуль 4. Базовые приемы Pandas\data\citibike-tripdata.csv')

# %%
bike_data.head()
# Out:
#                   starttime                  stoptime  start station id  \
# 0  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340             252.0
# 1  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810             314.0
# 2  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470            3142.0
# 3  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830             308.0
# 4  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080             345.0
#
#                 start station name  start station latitude  \
# 0     MacDougal St & Washington Sq               40.732264
# 1  Cadman Plaza West & Montague St               40.693830
# 2                  1 Ave & E 62 St               40.761227
# 3          St James Pl & Oliver St               40.713079
# 4                  W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# 0               -73.998522           366.0    Clinton Ave & Myrtle Ave
# ...

# %%
bike_data.tail()
# Out:
#                        starttime                  stoptime  start station id  \
# 299995  2018-09-05 19:08:27.8460  2018-09-05 19:15:51.4940             494.0
# 299996  2018-09-05 19:08:28.3700  2018-09-05 19:20:01.5080            3016.0
# 299997  2018-09-05 19:08:27.5090  2018-09-05 19:13:40.5060            3686.0
# 299998  2018-09-05 19:08:29.2300  2018-09-05 20:04:29.3220             254.0
# 299999  2018-09-05 19:08:29.7110  2018-09-05 19:12:14.7620            3496.0
#
#                start station name  start station latitude  \
# 299995            W 26 St & 8 Ave               40.747348
# 299996          Kent Ave & N 7 St               40.720368
# 299997  Gansevoort St & Hudson St               40.739448
# 299998            W 11 St & 6 Ave               40.735324
# 299999           1 Ave & E 110 St               40.792327
#
#         start station longitude  end station id           end station name  \
# ...

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  object
#  1   stoptime                 300000 non-null  object
#  2   start station id         299831 non-null  float64
#  3   start station name       299831 non-null  object
#  4   start station latitude   300000 non-null  float64
#  5   start station longitude  300000 non-null  float64
#  6   end station id           299831 non-null  float64
#  7   end station name         299831 non-null  object
#  8   end station latitude     300000 non-null  float64
#  9   end station longitude    300000 non-null  float64
#  10  bikeid                   300000 non-null  int64
#  11  usertype                 300000 non-null  object
#  12  birth year               300000 non-null  int64
# ...

# %%
bike_data['start station id'].value_counts()
# Out:
# start station id
# 281.0     1928
# 2006.0    1909
# 519.0     1873
# 514.0     1845
# 426.0     1835
#           ...
# 3432.0      15
# 3599.0      11
# 2005.0       9
# 3704.0       7
# 3583.0       6
# Name: count, Length: 759, dtype: int64

# %%
bike_data['bikeid'].value_counts()
# Out:
# bikeid
# 33887    107
# 34358    104
# 34159    103
# 34258    103
# 34314    102
#         ...
# 32682      1
# 18260      1
# 34554      1
# 34518      1
# 25794      1
# Name: count, Length: 10004, dtype: int64

# %%
bike_data['usertype'].value_counts(normalize=True)
# Out:
# usertype
# Subscriber    0.774007
# Customer      0.225993
# Name: proportion, dtype: float64

# %%
bike_data['gender'].value_counts()
# Out:
# gender
# 1    183582
# 2     74506
# 0     41912
# Name: count, dtype: int64

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  object
#  1   stoptime                 300000 non-null  object
#  2   start station id         299831 non-null  float64
#  3   start station name       299831 non-null  object
#  4   start station latitude   300000 non-null  float64
#  5   start station longitude  300000 non-null  float64
#  6   end station id           299831 non-null  float64
#  7   end station name         299831 non-null  object
#  8   end station latitude     300000 non-null  float64
#  9   end station longitude    300000 non-null  float64
#  10  bikeid                   300000 non-null  int64
#  11  usertype                 300000 non-null  object
#  12  birth year               300000 non-null  int64
# ...

# %%
bike_data['start station id'].nunique()
# Out:
# 759

# %%
bike_data['end station id'].nunique()
# Out:
# 765

# %%
bike_data['birth year'].max()
# Out:
# np.int64(2002)

# %%
bike_data['start station name'].value_counts()
# Out:
# start station name
# Grand Army Plaza & Central Park S    1928
# Central Park S & 6 Ave               1909
# Pershing Square North                1873
# 12 Ave & W 40 St                     1845
# West St & Chambers St                1835
#                                      ...
# NYCBS Depot - GOW                      15
# Franklin Ave & Empire Blvd             11
# Railroad Ave & Kay Ave                  9
# 47 Ave & Skillman Ave                   7
# Eastern Pkwy & Washington Ave           6
# Name: count, Length: 759, dtype: int64

# %%
bike_data['end station name'].value_counts()
# Out:
# end station name
# West St & Chambers St          1963
# 12 Ave & W 40 St               1909
# Pershing Square North          1850
# Central Park S & 6 Ave         1828
# E 17 St & Broadway             1804
#                                ...
# Exchange Place                    3
# Union St                          1
# Montrose Ave & Bushwick Ave       1
# Warren St                         1
# Liberty Light Rail                1
# Name: count, Length: 765, dtype: int64

# %%
bike_data.describe(include=['object'])
# Out:
#                        starttime                  stoptime  \
# count                     300000                    300000
# unique                    299836                    299813
# top     2018-09-02 19:44:40.3680  2018-09-01 15:57:41.0310
# freq                           2                         2
#
#                        start station name       end station name    usertype
# count                              299831                 299831      300000
# unique                                759                    765           2
# top     Grand Army Plaza & Central Park S  West St & Chambers St  Subscriber
# freq                                 1928                   1963      232202

# %%
bike_data_copy = bike_data.copy()
bike_data_copy.head()
# Out:
#                   starttime                  stoptime  start station id  \
# 0  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340             252.0
# 1  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810             314.0
# 2  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470            3142.0
# 3  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830             308.0
# 4  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080             345.0
#
#                 start station name  start station latitude  \
# 0     MacDougal St & Washington Sq               40.732264
# 1  Cadman Plaza West & Montague St               40.693830
# 2                  1 Ave & E 62 St               40.761227
# 3          St James Pl & Oliver St               40.713079
# 4                  W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# 0               -73.998522           366.0    Clinton Ave & Myrtle Ave
# ...

# %%
bike_data_copy = bike_data_copy.drop(['start station id', 'end station id'], axis=1)
bike_data_copy.shape
# Out:
# (300000, 12)

# %%
#age = pd.to_datetime(bike_data_copy['birth year'])
#age = age.dt.year
#date = pd.to_datetime('2018')
#date = date.dt.year
bike_data_copy['age'] = 2018 - bike_data_copy['birth year']
#delta_days = melb_df['Date'] - pd.to_datetime('2016-01-01') 

bike_data_copy['age']
# Out:
# 0         38
# 1         49
# 2         43
# 3         34
# 4         24
#           ..
# 299995    28
# 299996    36
# 299997    27
# 299998    43
# 299999    52
# Name: age, Length: 300000, dtype: int64

# %%
bike_data_copy[bike_data_copy['age'] > 60].value_counts()
# Out:
# starttime                 stoptime                  start station name                 start station latitude  start station longitude  end station name         end station latitude  end station longitude  bikeid  usertype    birth year  gender  age
# 2018-09-05 19:08:26.2640  2018-09-05 19:44:53.7800  Columbus Ave & W 72 St             40.777057               -73.978985               Hudson St & Reade St     40.716250             -74.009106             26377   Subscriber  1952        1       66     1
# 2018-09-01 00:04:20.9200  2018-09-01 00:11:21.6180  Grand Army Plaza & Central Park S  40.764397               -73.973715               Broadway & W 53 St       40.763441             -73.982681             24824   Subscriber  1955        2       63     1
# ...

# %%
bike_data_copy.drop('birth year', axis = 1)
# Out:
#                        starttime                  stoptime  \
# 0       2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340
# 1       2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810
# 2       2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470
# 3       2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830
# 4       2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080
# ...                          ...                       ...
# 299995  2018-09-05 19:08:27.8460  2018-09-05 19:15:51.4940
# 299996  2018-09-05 19:08:28.3700  2018-09-05 19:20:01.5080
# 299997  2018-09-05 19:08:27.5090  2018-09-05 19:13:40.5060
# 299998  2018-09-05 19:08:29.2300  2018-09-05 20:04:29.3220
# 299999  2018-09-05 19:08:29.7110  2018-09-05 19:12:14.7620
#
#                      start station name  start station latitude  \
# 0          MacDougal St & Washington Sq               40.732264
# 1       Cadman Plaza West & Montague St               40.693830
# ...

# %%
bike_data_copy_1 = bike_data_copy.copy()
bike_data_copy_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  object
#  1   stoptime                 300000 non-null  object
#  2   start station name       299831 non-null  object
#  3   start station latitude   300000 non-null  float64
#  4   start station longitude  300000 non-null  float64
#  5   end station name         299831 non-null  object
#  6   end station latitude     300000 non-null  float64
#  7   end station longitude    300000 non-null  float64
#  8   bikeid                   300000 non-null  int64
#  9   usertype                 300000 non-null  object
#  10  birth year               300000 non-null  int64
#  11  gender                   300000 non-null  int64
#  12  age                      300000 non-null  int64
# dtypes: float64(4), int64(4), object(5)
# ...

# %%
starttime = pd.to_datetime(bike_data_copy_1['starttime'])

stopttime = pd.to_datetime(bike_data_copy_1['stoptime'])

trip_duration = stopttime - starttime


bike_data_copy_1['trip_duration'] = trip_duration
bike_data_copy_1['trip_duration'][3]
#bike_data_copy_1
# Out:
# Timedelta('0 days 00:07:16.837000')
