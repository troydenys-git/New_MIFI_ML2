# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
class LinearRegressionManual() :

    def __init__(self, learning_rate, iterations) :
        # не забудьте сохранить параметры во внутренние переменные
        self.learning_rate = learning_rate
        self.iterations = iterations
        self.weights = None
       

    def fit(self, X, Y) :
        # классический метод для тренировки
        X = np.hstack((np.ones((X.shape[0], 1)), X))
        self.weights = np.zeros((X.shape[1]))
        
       
        for i in range(self.iterations) :
            # здесь код изменения весов, правильнее его вынести в отдельный метод
            self.update_weights(X, Y)
            
        self.W = self.weights[1:] 
        self.b = self.weights[0]
        
        return self

    def update_weights(self, X, Y) :
            # здесь код для изменения весов
        y_pred = np.dot(X, self.weights)
        gradients = np.dot(X.T, (y_pred - Y)) / Y.shape[0]
        self.weights -= self.learning_rate * gradients
        return self
        

    def predict( self, X ) :
            # а тут предсказание значений
        X = np.hstack((np.ones((X.shape[0], 1)), X))
        return np.dot(X, self.weights)

# %%
import numpy as np

X = np.array([
    [1, 1],
    [2, 1],
    [3, 1],
    [4, 1]
])
Y = np.array([3, 5, 7, 9])  # y = 2*x1 + 1*x2

model = LinearRegressionManual(0.1, 2000)
model.fit(X, Y)

print(' '.join(f'{w:.3f}' for w in model.W), f'{model.b:.3f}')
# Out:
# 2.000 0.500 0.500

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

print('Mean Absolute Error:', mean_absolute_error(y, y_pred))
print('Mean Squared Error:', mean_squared_error(y, y_pred))
print('R2 score:', r2_score(y, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# ----> 3 print('Mean Absolute Error:', mean_absolute_error(y, y_pred))
#       4 print('Mean Squared Error:', mean_squared_error(y, y_pred))
#       5 print('R2 score:', r2_score(y, y_pred))
#
# NameError: name 'y_pred' is not defined

# %%
x = np.array([-4, -3, -2, -1, 0, 1, 2, 3, 4]).reshape((-1, 1))
y = np.array([16, 9, 4, 1, 0, 1, 4, 9, 16])

# %%
model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 model = LinearRegression()
#       2 model.fit(x, y)
#       3 y_pred = model.predict(x)
#
# TypeError: LinearRegression.__init__() missing 2 required positional arguments: 'learning_rate' and 'iterations'
