# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import tree
from sklearn import model_selection
from sklearn import metrics
from sklearn import *
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, roc_auc_score, f1_score, make_scorer
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
path = r'C:\Users\troyd\OneDrive\Desktop\data\AirPass.csv'
AirPass = pd.read_csv(path)

# %%
AirPass.drop('Unnamed: 0', axis=1, inplace=True)

# %%
AirPass.head(3)
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
# 2                       2  ...                       5                 4
#
#    Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                 3                 4                4                 5
# 1                 5                 3                1                 4
# 2                 3                 4                4                 4
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0            5                          25                      18.0
# 1            1                           1                       6.0
# 2            5                           0                       0.0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
#
# [3 rows x 24 columns]

# %%
AirPass.isna().sum()
# Out:
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# dtype: int64

# %%
AirPass['Arrival Delay in Minutes'] = AirPass['Arrival Delay in Minutes'].fillna(AirPass['Arrival Delay in Minutes'].median())
AirPass['Arrival Delay in Minutes'].mean()
# Out:
# np.float64(15.133392362180475)

# %%
satisfy = AirPass.groupby(['Gender'])
satisfy['satisfaction'].value_counts(normalize=True)
# Out:
# Gender  satisfaction
# Female  neutral or dissatisfied    0.572629
#         satisfied                  0.427371
# Male    neutral or dissatisfied    0.560525
#         satisfied                  0.439475
# Name: proportion, dtype: float64

# %%
satisfy = AirPass.groupby(['Type of Travel'])
satisfy['satisfaction'].value_counts(normalize=True)
# Out:
# Type of Travel   satisfaction
# Business travel  satisfied                  0.582597
#                  neutral or dissatisfied    0.417403
# Personal Travel  neutral or dissatisfied    0.898322
#                  satisfied                  0.101678
# Name: proportion, dtype: float64

# %%
satisfy = AirPass.groupby(['Class'])
satisfy['satisfaction'].value_counts(normalize=True)
# Out:
# Class     satisfaction
# Business  satisfied                  0.694251
#           neutral or dissatisfied    0.305749
# Eco       neutral or dissatisfied    0.813862
#           satisfied                  0.186138
# Eco Plus  neutral or dissatisfied    0.753936
#           satisfied                  0.246064
# Name: proportion, dtype: float64

# %%
AirPass['satisfaction'] = AirPass['satisfaction'].map({'neutral or dissatisfied':0 , 'satisfied':1})
AirPass['Customer Type'] = AirPass['Customer Type'].map({'Loyal Customer':1, 'disloyal Customer':0})
AirPass['Type of Travel'] = AirPass['Type of Travel'].map({'Personal Travel':0, 'Business travel':1})
AirPass['Gender'] = AirPass['Gender'].map({'Male': 0, 'Female': 1})

# %%
AirPass=pd.get_dummies(AirPass)
AirPass.shape
# Out:
# (103904, 26)

# %%
Y = AirPass['satisfaction'] 
X = AirPass.drop('satisfaction', axis = 1)
 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = 26)
X_test.shape
# Out:
# (20781, 25)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train) 
X_train = scaler.transform(X_train) 
X_test = scaler.transform(X_test) 
X_test[0][0]
# Out:
# np.float64(0.9408251379303)

# %%
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression()
model_lr.fit(X_train, Y_train)
preds_test = model_lr.predict(X_test)
f1_score(preds_test, Y_test)
# Out:
# 0.8547046934650797

# %%
model_ada = AdaBoostClassifier(DecisionTreeClassifier(random_state=26),random_state=26,learning_rate=0.01)

model_ada.fit(X_train, Y_train)
preds_test = model_ada.predict(X_test)
f1_score(preds_test, Y_test)
# Out:
# 0.9404794558121674

# %%
model_for_gs = GradientBoostingClassifier()
params = {"n_estimators":2**np.arange(8), "learning_rate":0.1**np.arange(3)}
gs = GridSearchCV(model_for_gs, 
                  params, 
                  cv=3, 
                  scoring=make_scorer(f1_score),
                  verbose=5)
 
gs.fit(X_train, Y_train)
 
print("Лучшие гиперпараметры:", gs.best_params_)
print("Лучшее значение метрики:", gs.best_score_)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [CV 1/3] END .learning_rate=1.0, n_estimators=1;, score=0.873 total time=   0.2s
# [CV 2/3] END .learning_rate=1.0, n_estimators=1;, score=0.870 total time=   0.2s
# [CV 3/3] END .learning_rate=1.0, n_estimators=1;, score=0.871 total time=   0.2s
# [CV 1/3] END .learning_rate=1.0, n_estimators=2;, score=0.880 total time=   0.4s
# [CV 2/3] END .learning_rate=1.0, n_estimators=2;, score=0.878 total time=   0.5s
# [CV 3/3] END .learning_rate=1.0, n_estimators=2;, score=0.875 total time=   0.6s
# [CV 1/3] END .learning_rate=1.0, n_estimators=4;, score=0.901 total time=   1.3s
# [CV 2/3] END .learning_rate=1.0, n_estimators=4;, score=0.896 total time=   1.4s
# [CV 3/3] END .learning_rate=1.0, n_estimators=4;, score=0.897 total time=   1.2s
# [CV 1/3] END .learning_rate=1.0, n_estimators=8;, score=0.920 total time=   2.2s
# [CV 2/3] END .learning_rate=1.0, n_estimators=8;, score=0.920 total time=   2.1s
# [CV 3/3] END .learning_rate=1.0, n_estimators=8;, score=0.919 total time=   2.4s
# [CV 1/3] END learning_rate=1.0, n_estimators=16;, score=0.935 total time=   4.9s
# [CV 2/3] END learning_rate=1.0, n_estimators=16;, score=0.938 total time=   4.4s
# [CV 3/3] END learning_rate=1.0, n_estimators=16;, score=0.933 total time=   5.1s
# [CV 1/3] END learning_rate=1.0, n_estimators=32;, score=0.943 total time=   9.6s
# [CV 2/3] END learning_rate=1.0, n_estimators=32;, score=0.945 total time=   8.9s
# [CV 3/3] END learning_rate=1.0, n_estimators=32;, score=0.944 total time=   8.9s
# [CV 1/3] END learning_rate=1.0, n_estimators=64;, score=0.947 total time=  16.8s
# [CV 2/3] END learning_rate=1.0, n_estimators=64;, score=0.947 total time=  16.3s
# [CV 3/3] END learning_rate=1.0, n_estimators=64;, score=0.948 total time=  17.1s
# [CV 1/3] END learning_rate=1.0, n_estimators=128;, score=0.949 total time=  35.8s
# [CV 2/3] END learning_rate=1.0, n_estimators=128;, score=0.949 total time=  35.8s
# [CV 3/3] END learning_rate=1.0, n_estimators=128;, score=0.949 total time=  33.7s
# [CV 1/3] END .learning_rate=0.1, n_estimators=1;, score=0.000 total time=   0.2s
# [CV 2/3] END .learning_rate=0.1, n_estimators=1;, score=0.000 total time=   0.2s
# [CV 3/3] END .learning_rate=0.1, n_estimators=1;, score=0.000 total time=   0.2s
# [CV 1/3] END .learning_rate=0.1, n_estimators=2;, score=0.765 total time=   0.5s
# [CV 2/3] END .learning_rate=0.1, n_estimators=2;, score=0.802 total time=   0.5s
# [CV 3/3] END .learning_rate=0.1, n_estimators=2;, score=0.794 total time=   0.5s
# [CV 1/3] END .learning_rate=0.1, n_estimators=4;, score=0.880 total time=   0.9s
# [CV 2/3] END .learning_rate=0.1, n_estimators=4;, score=0.880 total time=   1.0s
# [CV 3/3] END .learning_rate=0.1, n_estimators=4;, score=0.878 total time=   1.2s
# [CV 1/3] END .learning_rate=0.1, n_estimators=8;, score=0.881 total time=   2.2s
# [CV 2/3] END .learning_rate=0.1, n_estimators=8;, score=0.878 total time=   1.9s
# [CV 3/3] END .learning_rate=0.1, n_estimators=8;, score=0.881 total time=   2.9s
# [CV 1/3] END learning_rate=0.1, n_estimators=16;, score=0.886 total time=   4.4s
# [CV 2/3] END learning_rate=0.1, n_estimators=16;, score=0.887 total time=   4.8s
# [CV 3/3] END learning_rate=0.1, n_estimators=16;, score=0.889 total time=   4.2s
# [CV 1/3] END learning_rate=0.1, n_estimators=32;, score=0.914 total time=   9.5s
# [CV 2/3] END learning_rate=0.1, n_estimators=32;, score=0.919 total time=   8.2s
# [CV 3/3] END learning_rate=0.1, n_estimators=32;, score=0.910 total time=   8.4s
# [CV 1/3] END learning_rate=0.1, n_estimators=64;, score=0.928 total time=  16.4s
# [CV 2/3] END learning_rate=0.1, n_estimators=64;, score=0.929 total time=  16.4s
# [CV 3/3] END learning_rate=0.1, n_estimators=64;, score=0.929 total time=  15.8s
# [CV 1/3] END learning_rate=0.1, n_estimators=128;, score=0.939 total time=  31.5s
# [CV 2/3] END learning_rate=0.1, n_estimators=128;, score=0.938 total time=  31.0s
# [CV 3/3] END learning_rate=0.1, n_estimators=128;, score=0.938 total time=  32.1s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=1;, score=0.000 total time=   0.2s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=1;, score=0.000 total time=   0.2s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=1;, score=0.000 total time=   0.2s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=2;, score=0.000 total time=   0.4s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=2;, score=0.000 total time=   0.4s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=2;, score=0.000 total time=   0.4s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=4;, score=0.000 total time=   1.0s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=4;, score=0.000 total time=   1.2s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=4;, score=0.000 total time=   1.2s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=8;, score=0.000 total time=   2.1s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=8;, score=0.000 total time=   1.9s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=8;, score=0.000 total time=   2.3s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=16;, score=0.765 total time=   4.1s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=16;, score=0.802 total time=   4.4s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=16;, score=0.757 total time=   4.4s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=32;, score=0.878 total time=   8.4s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=32;, score=0.860 total time=   8.7s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=32;, score=0.858 total time=   8.1s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=64;, score=0.881 total time=  15.9s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=64;, score=0.877 total time=  15.5s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=64;, score=0.877 total time=  16.3s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=128;, score=0.886 total time=  31.1s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=128;, score=0.886 total time=  31.4s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=128;, score=0.885 total time=  30.9s
# Лучшие гиперпараметры: {'learning_rate': np.float64(1.0), 'n_estimators': np.int64(128)}
# Лучшее значение метрики: 0.9491390587774934

# %%
from xgboost import XGBClassifier
model_xgb = XGBClassifier(random_state=26)
model_xgb.fit(X_train,Y_train)
preds_test = model_xgb.predict(X_test)
f1_score(preds_test, Y_test)
# Out:
# 0.9573723114544546

# %%
model = CatBoostClassifier(random_state=26)
model.fit(X_train, y_train)
preds_class = model.predict(X_test)
f1_score(preds_class, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 model = CatBoostClassifier(random_state=26)
#       2 model.fit(X_train, y_train)
#       3 preds_class = model.predict(X_test)
#
# NameError: name 'CatBoostClassifier' is not defined

# %%
pd.DataFrame(
    {
        "feature_importance": model_ada.get_feature_importance(),
        "feature_names": AirPass.drop(columns="satisfaction").columns,
    }
).sort_values(by=["feature_importance"], ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 3
#       1 pd.DataFrame(
#       2     {
# ----> 3         "feature_importance": model_ada.get_feature_importance(),
#       4         "feature_names": AirPass.drop(columns="satisfaction").columns,
#       5     }
#       6 ).sort_values(by=["feature_importance"], ascending=False)
#
# AttributeError: 'AdaBoostClassifier' object has no attribute 'get_feature_importance'
