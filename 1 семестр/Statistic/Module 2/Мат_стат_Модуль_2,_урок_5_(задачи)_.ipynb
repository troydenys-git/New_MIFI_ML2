# %%
## НЕ ТРОГАЙТЕ ЭТОТ КОД ДЛЯ ГАРАНТИИ ВОСПРОИЗВОДИМОСТИ РЕЗУЛЬТАТА
import numpy as np
from   scipy.stats import uniform
from   scipy.stats import norm
from   scipy.stats import expon
from   scipy.stats import laplace
from   scipy.stats import pareto
from   scipy.stats import rayleigh

import matplotlib.pyplot as plt


np.random.seed(100)
## НЕ ТРОГАЙТЕ ЭТОТ КОД ДЛЯ ГАРАНТИИ ВОСПРОИЗВОДИМОСТИ РЕЗУЛЬТАТА

# %% [markdown]
# **Задача 5.1**
#
# Дано равномерное распределение $U[2; 9]$. Найдите вероятность попадания в интервал $[4; 8]$, среднее и дисперсию.

# %%
#Заполните пропуски "___"

# Определите параметры распределения
a = ___
b = ___

# Вероятность попадания в [4, 8]
prob = ___

# Среднее значение
mean = ___

# Дисперсия
variance = ___

print("Вероятность:", prob)
print("Среднее:"    , mean)
print("Дисперсия:"  , variance)

# %% [markdown]
# **Задача 5.2**
#
# Найдите $c$, если $P(X<c)=0.85$ для $X\sim U[0; 12]$.

# %%
#Заполните пропуски "___"

# Определим параметры распределения
a = ___
b = ___

# Найдём c так, что F(c) = 0.85
c = ___

print("Значение c:", c)

# %% [markdown]
# **Задача 5.3**
#
# Для $X\sim N(12,3)$ вычислите $P(X<9)$, $P(4<X<6)$, $P(∣X−10∣<2)$.

# %%
#Заполните пропуски "___"


# Параметры распределения
mu = ___
sigma = ___

# Вычисления
p1 = ___
p2 = ___
p3 = ___

print("P(X < 9):", p1)
print("P(4 < X < 6):", p2)
print("P(|X - 10| < 2):", p3)

# %% [markdown]
# **Задача 5.4**
#
# Рост студентов имеет $\mu=185$ см, $\sigma=15$ см. Какова вероятность, что рост $> 200$ см?

# %%
#Заполните пропуски "___"

# Параметры
mu = ___
sigma = ___

# Вероятность
p = ___

print("Вероятность:", p)

# %% [markdown]
# **Задача 5.5**
#
# Для экспоненциального распределения со средним $1.5$ часа, найдите вероятности $P(X < 1)$ и $P(X > 3)$.

# %%
#Заполните пропуски "___"

# Параметр λ
lambda_val = ___

# Вероятности
p1 = ___  # P(X < 1)
p2 = ___  # P(X > 3)
mode = ___
median = ___

print("P(X < 1):", p1)
print("P(X > 3):", p2)
print("Мода:", mode)
print("Медиана:", median)

# %% [markdown]
# **Задача 5.6**
#
# Для $X∼E_\lambda(x)$, где $\lambda=1.5$, найдите $P(X>4)$.

# %%
#Заполните пропуски "___"

lambda_val = ___

# Вероятность
p = ___

print("P(X > 4):", p)

# %% [markdown]
# **Задача 5.7**
#
# Для $X\sim L_{\mu=0, b=1}$, найдите вероятности $P(X < 0)$, $P(|X| < 1)$ и дисперсию.

# %%
#Заполните пропуски "___"

# Параметры
mu = ___
b = ___

# Вероятности
p1 = ___  # P(X < 0)
p2 = ___  # P(|X| < 1)

# Дисперсия
variance = ___

print("P(X < 0):", p1)
print("P(|X| < 1):", p2)
print("Дисперсия:", variance)

# %% [markdown]
# **Задача 5.8**
#
# Для $X\sim Pareto(\alpha=2, x_m =10^4)$, найдите среднее, вероятность $P(X > 2 \star x_m)$ и медиану.

# %%
#Заполните пропуски "___"

# Параметры
alpha = ___
xm = ___

# Среднее
mean = ___

# Вероятность
p = ___  # P(X > 2 * xm)

# Медиана
median = ___

print("Среднее:", mean)
print("P(X > 2*xm):", p)
print("Медиана:", median)

# %% [markdown]
# Для $X\sim R_\sigma(x)$ (распределение Релея), где $\sigma=2$, найдите среднюю скорость, вероятность  $P(X < 3)$ и моду.

# %%
#Заполните пропуски "___"

# Параметр σ
sigma = ___

# Среднее
mean = ___

# Вероятность
p = ___  # P(X < 3)

# Мода
mode = ___

print("Среднее:", mean)
print("P(X < 3):", p)
print("Мода:", mode)
