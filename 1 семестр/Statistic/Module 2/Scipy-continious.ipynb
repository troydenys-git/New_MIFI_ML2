# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Настройки графиков
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))

# PDF
x = np.linspace(-1, 11, 5000)
ax1.plot(x, uniform.pdf(x), 'b', label='U(0,1)')
ax1.plot(x, uniform.pdf(x, loc=2, scale=5), 'r', label='U(2,7)')
ax1.plot(x, uniform.pdf(x, loc=8, scale=2), 'g', label='U(8,10)')
ax1.set_title('Функция плотности (PDF)')
ax1.grid(True)

# CDF
ax2.plot(x, uniform.cdf(x), 'b', label='U(0,1)')
ax2.plot(x, uniform.cdf(x, loc=2, scale=5), 'r', label='U(2,7)')
ax2.plot(x, uniform.cdf(x, loc=8, scale=2), 'g', label='U(8,10)')
ax2.set_title('Функция распределения (CDF)')
ax2.grid(True)

for ax in (ax1, ax2):
    ax.legend()
    ax.set_xlabel('x')
    ax.set_ylabel('f(x) / F(x)')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Настройки графиков
plt.figure(figsize=(15, 6))

# PDF
x = np.linspace(-10, 10, 1000)
plt.subplot(121)
for params in [(0,1), (5,3), (-5,0.5)]:
    plt.plot(x, norm.pdf(x, *params), 
             label=f'μ={params[0]}, σ={params[1]}')
plt.title('Функция плотности (PDF)')
plt.grid(True)

# CDF
plt.subplot(122)
for params in [(0,1), (5,3), (-5,0.5)]:
    plt.plot(x, norm.cdf(x, *params),
             label=f'μ={params[0]}, σ={params[1]}')
plt.title('Функция распределения (CDF)')
plt.grid(True)

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import expon

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# PDF
x = np.linspace(0, 5, 500)
for scale in [1, 1/0.2, 1/2]:
    ax1.plot(x, expon.pdf(x, scale=scale), 
             label=f'λ={1/scale:.1f}')
ax1.set_title('Функция плотности (PDF)')

# CDF
for scale in [1, 1/0.2, 1/2]:
    ax2.plot(x, expon.cdf(x, scale=scale), 
             label=f'λ={1/scale:.1f}')
ax2.set_title('Функция распределения (CDF)')

for ax in (ax1, ax2):
    ax.legend()
    ax.grid(True)
plt.show()

# %%
from scipy.stats import laplace
import matplotlib.pyplot as plt
import numpy as np
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# PDF
x = np.linspace(-10, 10, 500)
for (loc, scale) in [(0,1), (5,1), (0,4), (-5,0.5)]:
    ax1.plot(x, laplace.pdf(x, loc, scale),
             label=f'μ={loc}, b={scale}')
ax1.set_title('Функция плотности (PDF)')

# CDF
for (loc, scale) in [(0,1), (5,1), (0,4), (-5,0.5)]:
    ax2.plot(x, laplace.cdf(x, loc, scale),
             label=f'μ={loc}, b={scale}')
ax2.set_title('Функция распределения (CDF)')

for ax in (ax1, ax2):
    ax.legend()
    ax.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pareto

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# PDF
x = np.linspace(1, 10, 1000)
for (a, xm) in [(1,1), (2,1), (1,4), (0.5,1)]:
    ax1.plot(x, pareto.pdf(x, a, scale=xm), 
             label=f'α={a}, xₘ={xm}')
ax1.set_title('Функция плотности (PDF)')
ax1.set_ylim(0, 2.5)

# CDF
for (a, xm) in [(1,1), (2,1), (1,4), (0.5,1)]:
    ax2.plot(x, pareto.cdf(x, a, scale=xm),
             label=f'α={a}, xₘ={xm}')
ax2.set_title('Функция распределения (CDF)')

for ax in (ax1, ax2):
    ax.legend()
    ax.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import rayleigh

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# PDF
x = np.linspace(0, 5, 500)
for scale in [0.5, 1, 2, 3]:
    ax1.plot(x, rayleigh.pdf(x, scale=scale),
             label=f'σ={scale}')
ax1.set_title('Функция плотности (PDF)')
ax1.set_ylim(0, 1.2)

# CDF
for scale in [0.5, 1, 2, 3]:
    ax2.plot(x, rayleigh.cdf(x, scale=scale),
             label=f'σ={scale}')
ax2.set_title('Функция распределения (CDF)')

for ax in (ax1, ax2):
    ax.legend()
    ax.grid(True)
plt.show()

# %%
import pandas as pd
path = r'C:\Users\troyd\OneDrive\Desktop\Стажировка\Критерии.csv'
aaa = pd.read_csv(path, sep=';')
aaa
# Out:
#                                   Название  \
# 0        Полнота функциональных требований
# 1                     Детализация объектов
# 2                            Бизнес-логика
# 3                           Ролевая модель
# 4                               Отчетность
# 5   Технические и архитектурные требования
# 6                          Стек технологий
# 7                               Интеграции
# 8                           Инфраструктура
# 9                              Мобильность
# 10             Нефункциональные требования
# 11                      Производительность
# 12                              Надежность
# 13                            Безопасность
# 14                        Масштабируемость
# 15           Организация проекта и приемка
# 16                               Этапность
# 17                        Критерии приемки
# 18                         Миграция данных
# 19          Интеллектуальная собственность
# 20                Нормативное соответствие
# 21                        Законодательство
# 22                          Лицензирование
# 23                Требования к Исполнителю
# 24                            Квалификация
# 25                                    Опыт
#
#                                              Описание  Важность
# 0   Оценка того, насколько подробно описано, что д...  Высокая​
# 1   Наличие описания всех сущностей (например, жур...  Высокая​
# 2   Наличие прописанных правил поведения системы: ...  Высокая​
# 3   Наличие матрицы прав доступа: кто видит данные...  Высокая​
# 4   Перечень видов отчётов, их формы и источники д...  Средняя​
# 5   Критерии, определяющие жизнеспособность и реал...  Высокая​
# 6   Определённость по платформе, операционным сист...  Высокая​
# 7   Наличие описания интеграций (системы учёта, ка...  Высокая​
# 8   Наличие требований к вычислительным ресурсам (...  Высокая​
# 9   Наличие требований к работе с мобильных устрой...  Средняя​
# 10  Критерии качества системы (производительность,...  Высокая​
# 11  Определённость количественных показателей: вре...  Высокая​
# 12  Наличие показателей времени восстановления и д...  Высокая​
# 13  Наличие требований к шифрованию, аутентификаци...  Высокая​
# 14  Возможность увеличения производительности и пр...  Средняя​
# 15  Критерии, определяющие структуру проекта, конт...  Высокая​
# 16  Разбиение проекта на этапы с чётко определённы...  Средняя​
# 17  Наличие методики испытаний и классификатора ош...  Высокая​
# 18  Описание процесса переноса исторических данных...  Средняя​
# 19  Фиксация порядка передачи исключительных прав ...  Высокая​
# 20  Критерии проверки соответствия решения действу...  Высокая​
# 21  Учёт требований профильных законов и ведомстве...  Высокая​
# 22  Отсутствие противоречий и неопределённостей в ...  Средняя​
# 23  Критерии отбора подрядчика, позволяющие отсеят...  Высокая​
# 24  Наличие у исполнителя требуемых статусов партн...  Средняя​
# 25  Подтверждённый опыт реализации аналогичных про...  Высокая​

# %%
path = r'C:\IDE\Statistic\Module 2\asset-v1_SkillFactory+MIFIML-1sem+2024+type@asset+block@data.csv'
nnnn = pd.read_csv(path)

# %%
nnnn.head()
column_1 = nnnn['column_1']
column_2 = nnnn['column_2']
column_3 = nnnn['column_3']
column_4 = nnnn['column_4']
column_5 = nnnn['column_5']
column_6 = nnnn['column_6']

# %%
import seaborn as sns
sns.histplot(column_6, kde=True, color='green')
plt.title("Распределение с плотностью")
plt.show()

# %%
np.median(column_6)
# Out:
# np.float64(43.0)

# %%
plt.hist(column_1)
plt.show()
